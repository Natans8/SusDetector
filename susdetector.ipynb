# %%
import pandas as pd
import torch
from tqdm.notebook import tqdm
from diffusers import ZImagePipeline, FluxKontextInpaintPipeline, FluxPipeline
import ultralytics
from nunchaku import NunchakuZImageTransformer2DModel, NunchakuFluxTransformer2DModelV2
from nunchaku.utils import get_precision
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
import os
import random
import pandas

# %%
# Constants
ZIT_RANK = 32
yolo_model_name = 'models/yolo26x-seg.pt'

prompts = [
    # "People walking in a spacious airport terminal",
    "Children playing in a park",
    "Patients sitting in a hospital waiting room",
    "Shoppers walking through wide supermarket aisles",
    # "Travelers standing in a spacious airport check-in queue",
    "People standing on a train station platform",
    "Commuters waiting at a city bus stop",
    "Pedestrians walking on a wide city sidewalk",
    "Guests standing in a spacious hotel lobby",
    "Visitors walking through a museum gallery",
    "Students walking in a university corridor",
    "Customers waiting in line at a bank",
    "Employees walking in a modern office lobby",
    "Passengers walking in a subway station",
    #  "Crowd walking in a conference center hall",
    "Shoppers walking through a wise supermarket aisle"
]

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
dtype = torch.bfloat16 if torch.cuda.is_available() else torch.float32
print(f"Using device: {device}, dtype: {dtype}")

os.makedirs('data/backgrounds', exist_ok=True)
os.makedirs('data/images', exist_ok=True)
# Out:
# Using device: cuda, dtype: torch.bfloat16

# %%
# Utility functions
def display_image(img: Image.Image, title: str = "Image", box=None):
    img = img.copy()
    plt.figure(figsize=(6, 4))
    if box is not None:
        x1, y1, x2, y2 = box
        draw = ImageDraw.Draw(img)
        draw.rectangle([(x1, y1), (x2, y2)], outline='red', width=5)

    plt.imshow(img)
    plt.title(title)
    plt.axis("off")
    plt.show()


def display_masks(img: np.ndarray, mask_rgb: np.ndarray, overlay: np.ndarray):
    plt.figure(figsize=(14, 4))

    # Original image
    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title("Original")
    plt.axis("off")

    # Mask visualization
    plt.subplot(1, 3, 2)
    plt.imshow(mask_rgb)
    plt.title("Person Instance Masks")
    plt.axis("off")

    # Mask overlay
    plt.subplot(1, 3, 3)
    plt.imshow(overlay)
    plt.title("Overlay")
    plt.axis("off")
    plt.tight_layout()
    plt.show()

# %%
# Background image generation with Z-Image-Turbo Nunchaku

def load_zit_pipeline():
    rank = ZIT_RANK
    transformer = NunchakuZImageTransformer2DModel.from_pretrained(
        f"nunchaku-tech/nunchaku-z-image-turbo/svdq-{get_precision()}_r{rank}-z-image-turbo.safetensors")

    pipe = ZImagePipeline.from_pretrained("Tongyi-MAI/Z-Image-Turbo", transformer=transformer, torch_dtype=dtype)
    pipe.enable_model_cpu_offload()

    return pipe


def zit_generate(pipe, prompt: str, width: int = 1280, height: int = 720, seed=None) -> Image.Image:
    if not seed:
        seed = random.randint(0, 2 ** 31 - 1)
    generator = torch.Generator(device=device).manual_seed(seed)
    img = pipe(
        prompt=prompt,
        num_inference_steps=8, guidance_scale=0.0,
        generator=generator, width=width, height=height,
    ).images[0]

    return img

# %%
def load_flux_pipeline():
    transformer = NunchakuFluxTransformer2DModelV2.from_pretrained(
        f"nunchaku-tech/nunchaku-flux.1-dev/svdq-{get_precision()}_r32-flux.1-dev.safetensors")
    pipe = FluxPipeline.from_pretrained(
        "black-forest-labs/FLUX.1-dev", transformer=transformer, torch_dtype=torch.bfloat16)
    pipe.enable_model_cpu_offload()
    return pipe


def flux_generate(pipe: FluxPipeline, prompt: str, width: int = 1280, height: int = 720) -> Image.Image:
    image = pipe(prompt=prompt, guidance_scale=3.5, width=width, height=height).images[0]
    return image

# %%
def load_flux_kontext_pipeline():
    transformer = NunchakuFluxTransformer2DModelV2.from_pretrained(
        f"nunchaku-tech/nunchaku-flux.1-kontext-dev/svdq-{get_precision()}_r32-flux.1-kontext-dev.safetensors")

    pipe = FluxKontextInpaintPipeline.from_pretrained("black-forest-labs/FLUX.1-Kontext-dev", transformer=transformer,
                                                      torch_dtype=dtype)
    pipe.enable_model_cpu_offload()

    return pipe

# %%
def segment_persons(model, img: Image.Image, confidence: float = 0.25):
    img_np = np.array(img)
    h, w = img_np.shape[:2]

    res = model(img_np, conf=confidence, iou=0.5, verbose=False)[0]

    mask_rgb = np.zeros((h, w, 3), dtype=np.uint8)
    overlay = img_np.copy()
    box_list = []

    for i, cls in enumerate(res.boxes.cls.cpu().numpy()):
        if int(cls) == 0:  # person
            mask_data = res.masks.data[i].cpu().numpy()  # Get the raw mask data (at YOLO's inference resolution)
            resized_mask = cv2.resize(mask_data.astype(np.uint8), (w, h), interpolation=cv2.INTER_NEAREST)
            mask = resized_mask.astype(bool)

            color = np.random.randint(0, 256, 3)
            mask_rgb[mask] = color
            overlay[mask] = (0.5 * overlay[mask] + 0.5 * color).astype(np.uint8)
            box_list.append(res.boxes.xyxy[i].cpu().numpy().astype(int))

    return box_list, mask_rgb, overlay

# %%
def inpaint_image(pipe: FluxKontextInpaintPipeline, img: Image.Image, box: tuple, prompt: str,
                  neg: str = "") -> Image.Image:
    img_np = np.array(img)
    h, w = img_np.shape[:2]

    mask = np.zeros((h, w), dtype=np.uint8)
    x1, y1, x2, y2 = box
    mask[y1:y2, x1:x2] = 255  # White rectangle for inpainting area

    mask_pil = Image.fromarray(mask)

    seed = random.randint(0, 2 ** 31 - 1)
    generator = torch.Generator(device=device).manual_seed(seed)

    inpainted_img = pipe(
        prompt=prompt,
        image=img,
        mask_image=mask_pil,
        guidance_scale=2.5,
        generator=generator,
        strength=1.0).images[0]

    return inpainted_img

# %%
torch.cuda.empty_cache()
pipeline = load_zit_pipeline()
# Out:
# quantization_config: {'method': 'svdquant', 'weight': {'dtype': 'int4', 'scale_dtype': None, 'group_size': 64}, 'activation': {'dtype': 'int4', 'scale_dtype': None, 'group_size': 64}, 'rank': 32, 'skip_refiners': False}, rank=32, skip_refiners=False
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
prompt = random.choice(prompts)
image = zit_generate(pipeline, prompt, width=1280, height=720)
display_image(image, title=prompt)

# %%
boxes, masks, mask_overlay = segment_persons(ultralytics.YOLO(yolo_model_name), image, confidence=0.75)
display_masks(np.array(image), masks, mask_overlay)

# %%
torch.cuda.empty_cache()

inpaint_pipeline = load_flux_kontext_pipeline()

# %%
box = random.choice(boxes)
display_image(image, title=prompt, box=box)

# %%
inpaint_prompt = "Remove the person"
inpainted_image = inpaint_image(inpaint_pipeline, image, box, prompt=inpaint_prompt)
display_image(inpainted_image, title="After Removing Person", box=box)

# %%
inpaint_prompt2 = "Add a suitcase on the ground"
x1, y1, x2, y2 = box
box2 = (x1, int(y1 + 0.4 * abs(y2 - y1)), x2, y2)
inpainted_image2 = inpaint_image(inpaint_pipeline, inpainted_image, box2, prompt=inpaint_prompt2)
display_image(inpainted_image2, title="Inpainted Image", box=box2)

# %%
prompt_samples = {}
num_seeds = 5
seeds = [random.randint(0, 2 ** 31 - 1) for _ in range(num_seeds)]
for prompt in prompts:
    prompt_samples[prompt] = {}
    for seed in seeds:
        prompt_samples[prompt][seed] = zit_generate(pipeline, prompt, width=1280, height=720, seed=seed)

# %%
n_prompts = len(prompts)
n_seeds = 5

fig, axes = plt.subplots(n_prompts, n_seeds, figsize=(15, 3 * n_prompts))

for i, (prompt, images) in enumerate(prompt_samples.items()):
    for j, (seed, image) in enumerate(images.items()):
        ax = axes[i, j] if n_prompts > 1 else axes[0, j]
        ax.imshow(image)
        ax.axis('off')
        # Add title to first column
        if j == 0:
            ax.set_ylabel(prompt[:30] + '...', rotation=0, labelpad=50, va='center')

        # Add seed as column title
        if i == 0:
            ax.set_title(f'Seed: {seed}')

plt.tight_layout()
plt.savefig('grid.png')
plt.show()

# %%
plt.show()

# %%
total = len(prompts) * 15
counter = 0

with tqdm(total=total) as pbar:
    for _ in range(15):
        for p in prompts:
            img = zit_generate(pipeline, p, width=1280, height=720)
            img.save(f'data/backgrounds/{counter}.png')
            counter = counter + 1
            pbar.update(1)
# Out:
#   0%|          | 0/195 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]

# %%
# Extract people bounding boxes from the backgrounds data
yolo_model = ultralytics.YOLO('models/yolo26x.pt')
box_results = yolo_model.predict(
    source=f'data/backgrounds/',
    project='data',
    name='people-box',
    save=True,
    imgsz=(1280, 720),
    iou=0.5,
    device='cuda',
    classes=[0],
    batch=4,
    save_txt=True,
    conf=0.65, )
# Out:
# WARNING imgsz=[1280, 720] must be multiple of max stride 32, updating to [1280, 736]
# image 1/195 C:\Projects\SusDetector2\dataset\backgrounds\0.png: 416x736 3 persons, 14.8ms
# image 2/195 C:\Projects\SusDetector2\dataset\backgrounds\1.png: 416x736 5 persons, 14.8ms
# image 3/195 C:\Projects\SusDetector2\dataset\backgrounds\10.png: 416x736 2 persons, 14.8ms
# image 4/195 C:\Projects\SusDetector2\dataset\backgrounds\100.png: 416x736 7 persons, 14.8ms
# image 5/195 C:\Projects\SusDetector2\dataset\backgrounds\101.png: 416x736 2 persons, 8.9ms
# image 6/195 C:\Projects\SusDetector2\dataset\backgrounds\102.png: 416x736 13 persons, 8.9ms
# image 7/195 C:\Projects\SusDetector2\dataset\backgrounds\103.png: 416x736 2 persons, 8.9ms
# image 8/195 C:\Projects\SusDetector2\dataset\backgrounds\104.png: 416x736 4 persons, 8.9ms
# image 9/195 C:\Projects\SusDetector2\dataset\backgrounds\105.png: 416x736 7 persons, 8.1ms
# image 10/195 C:\Projects\SusDetector2\dataset\backgrounds\106.png: 416x736 3 persons, 8.1ms
# image 11/195 C:\Projects\SusDetector2\dataset\backgrounds\107.png: 416x736 6 persons, 8.1ms
# image 12/195 C:\Projects\SusDetector2\dataset\backgrounds\108.png: 416x736 4 persons, 8.1ms
# image 13/195 C:\Projects\SusDetector2\dataset\backgrounds\109.png: 416x736 9 persons, 9.0ms
# image 14/195 C:\Projects\SusDetector2\dataset\backgrounds\11.png: 416x736 9 persons, 9.0ms
# image 15/195 C:\Projects\SusDetector2\dataset\backgrounds\110.png: 416x736 10 persons, 9.0ms
# image 16/195 C:\Projects\SusDetector2\dataset\backgrounds\111.png: 416x736 7 persons, 9.0ms
# image 17/195 C:\Projects\SusDetector2\dataset\backgrounds\112.png: 416x736 3 persons, 8.9ms
# image 18/195 C:\Projects\SusDetector2\dataset\backgrounds\113.png: 416x736 6 persons, 8.9ms
# image 19/195 C:\Projects\SusDetector2\dataset\backgrounds\114.png: 416x736 3 persons, 8.9ms
# image 20/195 C:\Projects\SusDetector2\dataset\backgrounds\115.png: 416x736 8 persons, 8.9ms
# image 21/195 C:\Projects\SusDetector2\dataset\backgrounds\116.png: 416x736 2 persons, 8.8ms
# image 22/195 C:\Projects\SusDetector2\dataset\backgrounds\117.png: 416x736 4 persons, 8.8ms
# image 23/195 C:\Projects\SusDetector2\dataset\backgrounds\118.png: 416x736 5 persons, 8.8ms
# image 24/195 C:\Projects\SusDetector2\dataset\backgrounds\119.png: 416x736 4 persons, 8.8ms
# image 25/195 C:\Projects\SusDetector2\dataset\backgrounds\12.png: 416x736 2 persons, 9.0ms
# image 26/195 C:\Projects\SusDetector2\dataset\backgrounds\120.png: 416x736 10 persons, 9.0ms
# image 27/195 C:\Projects\SusDetector2\dataset\backgrounds\121.png: 416x736 6 persons, 9.0ms
# image 28/195 C:\Projects\SusDetector2\dataset\backgrounds\122.png: 416x736 6 persons, 9.0ms
# image 29/195 C:\Projects\SusDetector2\dataset\backgrounds\123.png: 416x736 11 persons, 7.9ms
# image 30/195 C:\Projects\SusDetector2\dataset\backgrounds\124.png: 416x736 4 persons, 7.9ms
# image 31/195 C:\Projects\SusDetector2\dataset\backgrounds\125.png: 416x736 3 persons, 7.9ms
# image 32/195 C:\Projects\SusDetector2\dataset\backgrounds\126.png: 416x736 6 persons, 7.9ms
# image 33/195 C:\Projects\SusDetector2\dataset\backgrounds\127.png: 416x736 3 persons, 9.2ms
# image 34/195 C:\Projects\SusDetector2\dataset\backgrounds\128.png: 416x736 10 persons, 9.2ms
# image 35/195 C:\Projects\SusDetector2\dataset\backgrounds\129.png: 416x736 2 persons, 9.2ms
# image 36/195 C:\Projects\SusDetector2\dataset\backgrounds\13.png: 416x736 4 persons, 9.2ms
# image 37/195 C:\Projects\SusDetector2\dataset\backgrounds\130.png: 416x736 4 persons, 9.0ms
# image 38/195 C:\Projects\SusDetector2\dataset\backgrounds\131.png: 416x736 5 persons, 9.0ms
# image 39/195 C:\Projects\SusDetector2\dataset\backgrounds\132.png: 416x736 4 persons, 9.0ms
# image 40/195 C:\Projects\SusDetector2\dataset\backgrounds\133.png: 416x736 7 persons, 9.0ms
# image 41/195 C:\Projects\SusDetector2\dataset\backgrounds\134.png: 416x736 8 persons, 9.0ms
# image 42/195 C:\Projects\SusDetector2\dataset\backgrounds\135.png: 416x736 8 persons, 9.0ms
# image 43/195 C:\Projects\SusDetector2\dataset\backgrounds\136.png: 416x736 10 persons, 9.0ms
# image 44/195 C:\Projects\SusDetector2\dataset\backgrounds\137.png: 416x736 8 persons, 9.0ms
# image 45/195 C:\Projects\SusDetector2\dataset\backgrounds\138.png: 416x736 4 persons, 8.6ms
# image 46/195 C:\Projects\SusDetector2\dataset\backgrounds\139.png: 416x736 6 persons, 8.6ms
# image 47/195 C:\Projects\SusDetector2\dataset\backgrounds\14.png: 416x736 5 persons, 8.6ms
# image 48/195 C:\Projects\SusDetector2\dataset\backgrounds\140.png: 416x736 4 persons, 8.6ms
# image 49/195 C:\Projects\SusDetector2\dataset\backgrounds\141.png: 416x736 6 persons, 8.1ms
# image 50/195 C:\Projects\SusDetector2\dataset\backgrounds\142.png: 416x736 3 persons, 8.1ms
# image 51/195 C:\Projects\SusDetector2\dataset\backgrounds\143.png: 416x736 4 persons, 8.1ms
# image 52/195 C:\Projects\SusDetector2\dataset\backgrounds\144.png: 416x736 6 persons, 8.1ms
# image 53/195 C:\Projects\SusDetector2\dataset\backgrounds\145.png: 416x736 3 persons, 8.0ms
# image 54/195 C:\Projects\SusDetector2\dataset\backgrounds\146.png: 416x736 7 persons, 8.0ms
# image 55/195 C:\Projects\SusDetector2\dataset\backgrounds\147.png: 416x736 6 persons, 8.0ms
# image 56/195 C:\Projects\SusDetector2\dataset\backgrounds\148.png: 416x736 7 persons, 8.0ms
# image 57/195 C:\Projects\SusDetector2\dataset\backgrounds\149.png: 416x736 13 persons, 9.3ms
# image 58/195 C:\Projects\SusDetector2\dataset\backgrounds\15.png: 416x736 2 persons, 9.3ms
# image 59/195 C:\Projects\SusDetector2\dataset\backgrounds\150.png: 416x736 5 persons, 9.3ms
# image 60/195 C:\Projects\SusDetector2\dataset\backgrounds\151.png: 416x736 3 persons, 9.3ms
# image 61/195 C:\Projects\SusDetector2\dataset\backgrounds\152.png: 416x736 6 persons, 8.4ms
# image 62/195 C:\Projects\SusDetector2\dataset\backgrounds\153.png: 416x736 5 persons, 8.4ms
# image 63/195 C:\Projects\SusDetector2\dataset\backgrounds\154.png: 416x736 9 persons, 8.4ms
# image 64/195 C:\Projects\SusDetector2\dataset\backgrounds\155.png: 416x736 3 persons, 8.4ms
# image 65/195 C:\Projects\SusDetector2\dataset\backgrounds\156.png: 416x736 4 persons, 8.1ms
# image 66/195 C:\Projects\SusDetector2\dataset\backgrounds\157.png: 416x736 6 persons, 8.1ms
# image 67/195 C:\Projects\SusDetector2\dataset\backgrounds\158.png: 416x736 3 persons, 8.1ms
# image 68/195 C:\Projects\SusDetector2\dataset\backgrounds\159.png: 416x736 10 persons, 8.1ms
# image 69/195 C:\Projects\SusDetector2\dataset\backgrounds\16.png: 416x736 8 persons, 8.3ms
# image 70/195 C:\Projects\SusDetector2\dataset\backgrounds\160.png: 416x736 7 persons, 8.3ms
# image 71/195 C:\Projects\SusDetector2\dataset\backgrounds\161.png: 416x736 9 persons, 8.3ms
# image 72/195 C:\Projects\SusDetector2\dataset\backgrounds\162.png: 416x736 11 persons, 8.3ms
# image 73/195 C:\Projects\SusDetector2\dataset\backgrounds\163.png: 416x736 5 persons, 7.7ms
# image 74/195 C:\Projects\SusDetector2\dataset\backgrounds\164.png: 416x736 4 persons, 7.7ms
# image 75/195 C:\Projects\SusDetector2\dataset\backgrounds\165.png: 416x736 7 persons, 7.7ms
# image 76/195 C:\Projects\SusDetector2\dataset\backgrounds\166.png: 416x736 2 persons, 7.7ms
# image 77/195 C:\Projects\SusDetector2\dataset\backgrounds\167.png: 416x736 7 persons, 7.8ms
# image 78/195 C:\Projects\SusDetector2\dataset\backgrounds\168.png: 416x736 4 persons, 7.8ms
# image 79/195 C:\Projects\SusDetector2\dataset\backgrounds\169.png: 416x736 4 persons, 7.8ms
# image 80/195 C:\Projects\SusDetector2\dataset\backgrounds\17.png: 416x736 5 persons, 7.8ms
# image 81/195 C:\Projects\SusDetector2\dataset\backgrounds\170.png: 416x736 6 persons, 7.8ms
# image 82/195 C:\Projects\SusDetector2\dataset\backgrounds\171.png: 416x736 3 persons, 7.8ms
# image 83/195 C:\Projects\SusDetector2\dataset\backgrounds\172.png: 416x736 4 persons, 7.8ms
# image 84/195 C:\Projects\SusDetector2\dataset\backgrounds\173.png: 416x736 6 persons, 7.8ms
# image 85/195 C:\Projects\SusDetector2\dataset\backgrounds\174.png: 416x736 9 persons, 8.0ms
# image 86/195 C:\Projects\SusDetector2\dataset\backgrounds\175.png: 416x736 9 persons, 8.0ms
# image 87/195 C:\Projects\SusDetector2\dataset\backgrounds\176.png: 416x736 5 persons, 8.0ms
# image 88/195 C:\Projects\SusDetector2\dataset\backgrounds\177.png: 416x736 4 persons, 8.0ms
# image 89/195 C:\Projects\SusDetector2\dataset\backgrounds\178.png: 416x736 6 persons, 7.9ms
# image 90/195 C:\Projects\SusDetector2\dataset\backgrounds\179.png: 416x736 2 persons, 7.9ms
# image 91/195 C:\Projects\SusDetector2\dataset\backgrounds\18.png: 416x736 7 persons, 7.9ms
# image 92/195 C:\Projects\SusDetector2\dataset\backgrounds\180.png: 416x736 8 persons, 7.9ms
# image 93/195 C:\Projects\SusDetector2\dataset\backgrounds\181.png: 416x736 2 persons, 7.8ms
# image 94/195 C:\Projects\SusDetector2\dataset\backgrounds\182.png: 416x736 4 persons, 7.8ms
# image 95/195 C:\Projects\SusDetector2\dataset\backgrounds\183.png: 416x736 6 persons, 7.8ms
# image 96/195 C:\Projects\SusDetector2\dataset\backgrounds\184.png: 416x736 3 persons, 7.8ms
# image 97/195 C:\Projects\SusDetector2\dataset\backgrounds\185.png: 416x736 8 persons, 7.7ms
# image 98/195 C:\Projects\SusDetector2\dataset\backgrounds\186.png: 416x736 9 persons, 7.7ms
# image 99/195 C:\Projects\SusDetector2\dataset\backgrounds\187.png: 416x736 10 persons, 7.7ms
# image 100/195 C:\Projects\SusDetector2\dataset\backgrounds\188.png: 416x736 10 persons, 7.7ms
# image 101/195 C:\Projects\SusDetector2\dataset\backgrounds\189.png: 416x736 4 persons, 8.2ms
# image 102/195 C:\Projects\SusDetector2\dataset\backgrounds\19.png: 416x736 8 persons, 8.2ms
# image 103/195 C:\Projects\SusDetector2\dataset\backgrounds\190.png: 416x736 4 persons, 8.2ms
# image 104/195 C:\Projects\SusDetector2\dataset\backgrounds\191.png: 416x736 4 persons, 8.2ms
# image 105/195 C:\Projects\SusDetector2\dataset\backgrounds\192.png: 416x736 2 persons, 8.0ms
# image 106/195 C:\Projects\SusDetector2\dataset\backgrounds\193.png: 416x736 8 persons, 8.0ms
# image 107/195 C:\Projects\SusDetector2\dataset\backgrounds\194.png: 416x736 2 persons, 8.0ms
# image 108/195 C:\Projects\SusDetector2\dataset\backgrounds\2.png: 416x736 2 persons, 8.0ms
# image 109/195 C:\Projects\SusDetector2\dataset\backgrounds\20.png: 416x736 5 persons, 8.0ms
# image 110/195 C:\Projects\SusDetector2\dataset\backgrounds\21.png: 416x736 5 persons, 8.0ms
# image 111/195 C:\Projects\SusDetector2\dataset\backgrounds\22.png: 416x736 4 persons, 8.0ms
# image 112/195 C:\Projects\SusDetector2\dataset\backgrounds\23.png: 416x736 2 persons, 8.0ms
# image 113/195 C:\Projects\SusDetector2\dataset\backgrounds\24.png: 416x736 8 persons, 7.8ms
# image 114/195 C:\Projects\SusDetector2\dataset\backgrounds\25.png: 416x736 3 persons, 7.8ms
# image 115/195 C:\Projects\SusDetector2\dataset\backgrounds\26.png: 416x736 3 persons, 7.8ms
# image 116/195 C:\Projects\SusDetector2\dataset\backgrounds\27.png: 416x736 6 persons, 7.8ms
# image 117/195 C:\Projects\SusDetector2\dataset\backgrounds\28.png: 416x736 4 persons, 8.4ms
# image 118/195 C:\Projects\SusDetector2\dataset\backgrounds\29.png: 416x736 7 persons, 8.4ms
# image 119/195 C:\Projects\SusDetector2\dataset\backgrounds\3.png: 416x736 8 persons, 8.4ms
# image 120/195 C:\Projects\SusDetector2\dataset\backgrounds\30.png: 416x736 6 persons, 8.4ms
# image 121/195 C:\Projects\SusDetector2\dataset\backgrounds\31.png: 416x736 11 persons, 8.0ms
# image 122/195 C:\Projects\SusDetector2\dataset\backgrounds\32.png: 416x736 10 persons, 8.0ms
# image 123/195 C:\Projects\SusDetector2\dataset\backgrounds\33.png: 416x736 4 persons, 8.0ms
# image 124/195 C:\Projects\SusDetector2\dataset\backgrounds\34.png: 416x736 4 persons, 8.0ms
# image 125/195 C:\Projects\SusDetector2\dataset\backgrounds\35.png: 416x736 6 persons, 8.0ms
# image 126/195 C:\Projects\SusDetector2\dataset\backgrounds\36.png: 416x736 5 persons, 8.0ms
# image 127/195 C:\Projects\SusDetector2\dataset\backgrounds\37.png: 416x736 8 persons, 8.0ms
# image 128/195 C:\Projects\SusDetector2\dataset\backgrounds\38.png: 416x736 3 persons, 8.0ms
# image 129/195 C:\Projects\SusDetector2\dataset\backgrounds\39.png: 416x736 5 persons, 7.8ms
# image 130/195 C:\Projects\SusDetector2\dataset\backgrounds\4.png: 416x736 6 persons, 7.8ms
# image 131/195 C:\Projects\SusDetector2\dataset\backgrounds\40.png: 416x736 6 persons, 7.8ms
# image 132/195 C:\Projects\SusDetector2\dataset\backgrounds\41.png: 416x736 3 persons, 7.8ms
# image 133/195 C:\Projects\SusDetector2\dataset\backgrounds\42.png: 416x736 8 persons, 8.5ms
# image 134/195 C:\Projects\SusDetector2\dataset\backgrounds\43.png: 416x736 7 persons, 8.5ms
# image 135/195 C:\Projects\SusDetector2\dataset\backgrounds\44.png: 416x736 9 persons, 8.5ms
# image 136/195 C:\Projects\SusDetector2\dataset\backgrounds\45.png: 416x736 8 persons, 8.5ms
# image 137/195 C:\Projects\SusDetector2\dataset\backgrounds\46.png: 416x736 4 persons, 8.0ms
# image 138/195 C:\Projects\SusDetector2\dataset\backgrounds\47.png: 416x736 4 persons, 8.0ms
# image 139/195 C:\Projects\SusDetector2\dataset\backgrounds\48.png: 416x736 8 persons, 8.0ms
# image 140/195 C:\Projects\SusDetector2\dataset\backgrounds\49.png: 416x736 2 persons, 8.0ms
# image 141/195 C:\Projects\SusDetector2\dataset\backgrounds\5.png: 416x736 9 persons, 7.9ms
# image 142/195 C:\Projects\SusDetector2\dataset\backgrounds\50.png: 416x736 9 persons, 7.9ms
# image 143/195 C:\Projects\SusDetector2\dataset\backgrounds\51.png: 416x736 3 persons, 7.9ms
# image 144/195 C:\Projects\SusDetector2\dataset\backgrounds\52.png: 416x736 3 persons, 7.9ms
# image 145/195 C:\Projects\SusDetector2\dataset\backgrounds\53.png: 416x736 5 persons, 8.1ms
# image 146/195 C:\Projects\SusDetector2\dataset\backgrounds\54.png: 416x736 3 persons, 8.1ms
# image 147/195 C:\Projects\SusDetector2\dataset\backgrounds\55.png: 416x736 7 persons, 8.1ms
# image 148/195 C:\Projects\SusDetector2\dataset\backgrounds\56.png: 416x736 9 persons, 8.1ms
# image 149/195 C:\Projects\SusDetector2\dataset\backgrounds\57.png: 416x736 9 persons, 8.4ms
# image 150/195 C:\Projects\SusDetector2\dataset\backgrounds\58.png: 416x736 8 persons, 8.4ms
# image 151/195 C:\Projects\SusDetector2\dataset\backgrounds\59.png: 416x736 4 persons, 8.4ms
# image 152/195 C:\Projects\SusDetector2\dataset\backgrounds\6.png: 416x736 12 persons, 8.4ms
# image 153/195 C:\Projects\SusDetector2\dataset\backgrounds\60.png: 416x736 5 persons, 7.9ms
# image 154/195 C:\Projects\SusDetector2\dataset\backgrounds\61.png: 416x736 6 persons, 7.9ms
# image 155/195 C:\Projects\SusDetector2\dataset\backgrounds\62.png: 416x736 5 persons, 7.9ms
# image 156/195 C:\Projects\SusDetector2\dataset\backgrounds\63.png: 416x736 8 persons, 7.9ms
# image 157/195 C:\Projects\SusDetector2\dataset\backgrounds\64.png: 416x736 2 persons, 8.0ms
# image 158/195 C:\Projects\SusDetector2\dataset\backgrounds\65.png: 416x736 2 persons, 8.0ms
# image 159/195 C:\Projects\SusDetector2\dataset\backgrounds\66.png: 416x736 4 persons, 8.0ms
# image 160/195 C:\Projects\SusDetector2\dataset\backgrounds\67.png: 416x736 1 person, 8.0ms
# image 161/195 C:\Projects\SusDetector2\dataset\backgrounds\68.png: 416x736 5 persons, 8.0ms
# image 162/195 C:\Projects\SusDetector2\dataset\backgrounds\69.png: 416x736 6 persons, 8.0ms
# image 163/195 C:\Projects\SusDetector2\dataset\backgrounds\7.png: 416x736 3 persons, 8.0ms
# image 164/195 C:\Projects\SusDetector2\dataset\backgrounds\70.png: 416x736 8 persons, 8.0ms
# image 165/195 C:\Projects\SusDetector2\dataset\backgrounds\71.png: 416x736 12 persons, 11.3ms
# image 166/195 C:\Projects\SusDetector2\dataset\backgrounds\72.png: 416x736 4 persons, 11.3ms
# image 167/195 C:\Projects\SusDetector2\dataset\backgrounds\73.png: 416x736 4 persons, 11.3ms
# image 168/195 C:\Projects\SusDetector2\dataset\backgrounds\74.png: 416x736 7 persons, 11.3ms
# image 169/195 C:\Projects\SusDetector2\dataset\backgrounds\75.png: 416x736 3 persons, 12.0ms
# image 170/195 C:\Projects\SusDetector2\dataset\backgrounds\76.png: 416x736 6 persons, 12.0ms
# image 171/195 C:\Projects\SusDetector2\dataset\backgrounds\77.png: 416x736 2 persons, 12.0ms
# image 172/195 C:\Projects\SusDetector2\dataset\backgrounds\78.png: 416x736 5 persons, 12.0ms
# image 173/195 C:\Projects\SusDetector2\dataset\backgrounds\79.png: 416x736 6 persons, 10.7ms
# image 174/195 C:\Projects\SusDetector2\dataset\backgrounds\8.png: 416x736 3 persons, 10.7ms
# image 175/195 C:\Projects\SusDetector2\dataset\backgrounds\80.png: 416x736 3 persons, 10.7ms
# image 176/195 C:\Projects\SusDetector2\dataset\backgrounds\81.png: 416x736 6 persons, 10.7ms
# image 177/195 C:\Projects\SusDetector2\dataset\backgrounds\82.png: 416x736 6 persons, 11.2ms
# image 178/195 C:\Projects\SusDetector2\dataset\backgrounds\83.png: 416x736 6 persons, 11.2ms
# image 179/195 C:\Projects\SusDetector2\dataset\backgrounds\84.png: 416x736 12 persons, 11.2ms
# image 180/195 C:\Projects\SusDetector2\dataset\backgrounds\85.png: 416x736 6 persons, 11.2ms
# image 181/195 C:\Projects\SusDetector2\dataset\backgrounds\86.png: 416x736 4 persons, 10.8ms
# image 182/195 C:\Projects\SusDetector2\dataset\backgrounds\87.png: 416x736 7 persons, 10.8ms
# image 183/195 C:\Projects\SusDetector2\dataset\backgrounds\88.png: 416x736 2 persons, 10.8ms
# image 184/195 C:\Projects\SusDetector2\dataset\backgrounds\89.png: 416x736 10 persons, 10.8ms
# image 185/195 C:\Projects\SusDetector2\dataset\backgrounds\9.png: 416x736 7 persons, 10.6ms
# image 186/195 C:\Projects\SusDetector2\dataset\backgrounds\90.png: 416x736 2 persons, 10.6ms
# image 187/195 C:\Projects\SusDetector2\dataset\backgrounds\91.png: 416x736 5 persons, 10.6ms
# image 188/195 C:\Projects\SusDetector2\dataset\backgrounds\92.png: 416x736 5 persons, 10.6ms
# image 189/195 C:\Projects\SusDetector2\dataset\backgrounds\93.png: 416x736 3 persons, 10.6ms
# image 190/195 C:\Projects\SusDetector2\dataset\backgrounds\94.png: 416x736 7 persons, 10.6ms
# image 191/195 C:\Projects\SusDetector2\dataset\backgrounds\95.png: 416x736 10 persons, 10.6ms
# image 192/195 C:\Projects\SusDetector2\dataset\backgrounds\96.png: 416x736 8 persons, 10.6ms
# image 193/195 C:\Projects\SusDetector2\dataset\backgrounds\97.png: 416x736 10 persons, 14.3ms
# image 194/195 C:\Projects\SusDetector2\dataset\backgrounds\98.png: 416x736 3 persons, 14.3ms
# image 195/195 C:\Projects\SusDetector2\dataset\backgrounds\99.png: 416x736 4 persons, 14.3ms
# Speed: 1.3ms preprocess, 8.9ms inference, 0.6ms postprocess per image at shape (4, 3, 416, 736)
# Results saved to C:\Projects\SusDetector2\dataset\people-box
# 195 labels saved to C:\Projects\SusDetector2\dataset\people-box\labels

# %%
# Extract people segmentation from the backgrounds data
yolo_model = ultralytics.YOLO('models/yolo26x-seg.pt')
seg_results = yolo_model.predict(
    source=f'data/backgrounds/',
    project='data',
    name='people-seg',
    save=True,
    imgsz=(1280, 720),
    iou=0.5,
    device='cuda',
    classes=[0],
    batch=4,
    save_txt=True,
    conf=0.65, )
# Out:
# WARNING imgsz=[1280, 720] must be multiple of max stride 32, updating to [1280, 736]
# image 1/195 C:\Projects\SusDetector2\dataset\backgrounds\0.png: 416x736 3 persons, 12.7ms
# image 2/195 C:\Projects\SusDetector2\dataset\backgrounds\1.png: 416x736 5 persons, 12.7ms
# image 3/195 C:\Projects\SusDetector2\dataset\backgrounds\10.png: 416x736 2 persons, 12.7ms
# image 4/195 C:\Projects\SusDetector2\dataset\backgrounds\100.png: 416x736 8 persons, 12.7ms
# image 5/195 C:\Projects\SusDetector2\dataset\backgrounds\101.png: 416x736 2 persons, 10.8ms
# image 6/195 C:\Projects\SusDetector2\dataset\backgrounds\102.png: 416x736 12 persons, 10.8ms
# image 7/195 C:\Projects\SusDetector2\dataset\backgrounds\103.png: 416x736 2 persons, 10.8ms
# image 8/195 C:\Projects\SusDetector2\dataset\backgrounds\104.png: 416x736 4 persons, 10.8ms
# image 9/195 C:\Projects\SusDetector2\dataset\backgrounds\105.png: 416x736 7 persons, 10.7ms
# image 10/195 C:\Projects\SusDetector2\dataset\backgrounds\106.png: 416x736 3 persons, 10.7ms
# image 11/195 C:\Projects\SusDetector2\dataset\backgrounds\107.png: 416x736 6 persons, 10.7ms
# image 12/195 C:\Projects\SusDetector2\dataset\backgrounds\108.png: 416x736 5 persons, 10.7ms
# image 13/195 C:\Projects\SusDetector2\dataset\backgrounds\109.png: 416x736 9 persons, 10.4ms
# image 14/195 C:\Projects\SusDetector2\dataset\backgrounds\11.png: 416x736 8 persons, 10.4ms
# image 15/195 C:\Projects\SusDetector2\dataset\backgrounds\110.png: 416x736 10 persons, 10.4ms
# image 16/195 C:\Projects\SusDetector2\dataset\backgrounds\111.png: 416x736 7 persons, 10.4ms
# image 17/195 C:\Projects\SusDetector2\dataset\backgrounds\112.png: 416x736 3 persons, 10.3ms
# image 18/195 C:\Projects\SusDetector2\dataset\backgrounds\113.png: 416x736 6 persons, 10.3ms
# image 19/195 C:\Projects\SusDetector2\dataset\backgrounds\114.png: 416x736 3 persons, 10.3ms
# image 20/195 C:\Projects\SusDetector2\dataset\backgrounds\115.png: 416x736 7 persons, 10.3ms
# image 21/195 C:\Projects\SusDetector2\dataset\backgrounds\116.png: 416x736 2 persons, 10.4ms
# image 22/195 C:\Projects\SusDetector2\dataset\backgrounds\117.png: 416x736 5 persons, 10.4ms
# image 23/195 C:\Projects\SusDetector2\dataset\backgrounds\118.png: 416x736 5 persons, 10.4ms
# image 24/195 C:\Projects\SusDetector2\dataset\backgrounds\119.png: 416x736 4 persons, 10.4ms
# image 25/195 C:\Projects\SusDetector2\dataset\backgrounds\12.png: 416x736 2 persons, 10.3ms
# image 26/195 C:\Projects\SusDetector2\dataset\backgrounds\120.png: 416x736 11 persons, 10.3ms
# image 27/195 C:\Projects\SusDetector2\dataset\backgrounds\121.png: 416x736 6 persons, 10.3ms
# image 28/195 C:\Projects\SusDetector2\dataset\backgrounds\122.png: 416x736 7 persons, 10.3ms
# image 29/195 C:\Projects\SusDetector2\dataset\backgrounds\123.png: 416x736 11 persons, 10.5ms
# image 30/195 C:\Projects\SusDetector2\dataset\backgrounds\124.png: 416x736 4 persons, 10.5ms
# image 31/195 C:\Projects\SusDetector2\dataset\backgrounds\125.png: 416x736 3 persons, 10.5ms
# image 32/195 C:\Projects\SusDetector2\dataset\backgrounds\126.png: 416x736 6 persons, 10.5ms
# image 33/195 C:\Projects\SusDetector2\dataset\backgrounds\127.png: 416x736 3 persons, 10.3ms
# image 34/195 C:\Projects\SusDetector2\dataset\backgrounds\128.png: 416x736 9 persons, 10.3ms
# image 35/195 C:\Projects\SusDetector2\dataset\backgrounds\129.png: 416x736 2 persons, 10.3ms
# image 36/195 C:\Projects\SusDetector2\dataset\backgrounds\13.png: 416x736 4 persons, 10.3ms
# image 37/195 C:\Projects\SusDetector2\dataset\backgrounds\130.png: 416x736 4 persons, 10.4ms
# image 38/195 C:\Projects\SusDetector2\dataset\backgrounds\131.png: 416x736 5 persons, 10.4ms
# image 39/195 C:\Projects\SusDetector2\dataset\backgrounds\132.png: 416x736 4 persons, 10.4ms
# image 40/195 C:\Projects\SusDetector2\dataset\backgrounds\133.png: 416x736 9 persons, 10.4ms
# image 41/195 C:\Projects\SusDetector2\dataset\backgrounds\134.png: 416x736 9 persons, 10.6ms
# image 42/195 C:\Projects\SusDetector2\dataset\backgrounds\135.png: 416x736 8 persons, 10.6ms
# image 43/195 C:\Projects\SusDetector2\dataset\backgrounds\136.png: 416x736 10 persons, 10.6ms
# image 44/195 C:\Projects\SusDetector2\dataset\backgrounds\137.png: 416x736 8 persons, 10.6ms
# image 45/195 C:\Projects\SusDetector2\dataset\backgrounds\138.png: 416x736 4 persons, 10.4ms
# image 46/195 C:\Projects\SusDetector2\dataset\backgrounds\139.png: 416x736 5 persons, 10.4ms
# image 47/195 C:\Projects\SusDetector2\dataset\backgrounds\14.png: 416x736 5 persons, 10.4ms
# image 48/195 C:\Projects\SusDetector2\dataset\backgrounds\140.png: 416x736 3 persons, 10.4ms
# image 49/195 C:\Projects\SusDetector2\dataset\backgrounds\141.png: 416x736 7 persons, 10.3ms
# image 50/195 C:\Projects\SusDetector2\dataset\backgrounds\142.png: 416x736 3 persons, 10.3ms
# image 51/195 C:\Projects\SusDetector2\dataset\backgrounds\143.png: 416x736 4 persons, 10.3ms
# image 52/195 C:\Projects\SusDetector2\dataset\backgrounds\144.png: 416x736 6 persons, 10.3ms
# image 53/195 C:\Projects\SusDetector2\dataset\backgrounds\145.png: 416x736 3 persons, 10.2ms
# image 54/195 C:\Projects\SusDetector2\dataset\backgrounds\146.png: 416x736 9 persons, 10.2ms
# image 55/195 C:\Projects\SusDetector2\dataset\backgrounds\147.png: 416x736 6 persons, 10.2ms
# image 56/195 C:\Projects\SusDetector2\dataset\backgrounds\148.png: 416x736 7 persons, 10.2ms
# image 57/195 C:\Projects\SusDetector2\dataset\backgrounds\149.png: 416x736 12 persons, 10.3ms
# image 58/195 C:\Projects\SusDetector2\dataset\backgrounds\15.png: 416x736 2 persons, 10.3ms
# image 59/195 C:\Projects\SusDetector2\dataset\backgrounds\150.png: 416x736 5 persons, 10.3ms
# image 60/195 C:\Projects\SusDetector2\dataset\backgrounds\151.png: 416x736 3 persons, 10.3ms
# image 61/195 C:\Projects\SusDetector2\dataset\backgrounds\152.png: 416x736 6 persons, 10.2ms
# image 62/195 C:\Projects\SusDetector2\dataset\backgrounds\153.png: 416x736 5 persons, 10.2ms
# image 63/195 C:\Projects\SusDetector2\dataset\backgrounds\154.png: 416x736 8 persons, 10.2ms
# image 64/195 C:\Projects\SusDetector2\dataset\backgrounds\155.png: 416x736 2 persons, 10.2ms
# image 65/195 C:\Projects\SusDetector2\dataset\backgrounds\156.png: 416x736 4 persons, 11.1ms
# image 66/195 C:\Projects\SusDetector2\dataset\backgrounds\157.png: 416x736 8 persons, 11.1ms
# image 67/195 C:\Projects\SusDetector2\dataset\backgrounds\158.png: 416x736 3 persons, 11.1ms
# image 68/195 C:\Projects\SusDetector2\dataset\backgrounds\159.png: 416x736 9 persons, 11.1ms
# image 69/195 C:\Projects\SusDetector2\dataset\backgrounds\16.png: 416x736 7 persons, 10.4ms
# image 70/195 C:\Projects\SusDetector2\dataset\backgrounds\160.png: 416x736 6 persons, 10.4ms
# image 71/195 C:\Projects\SusDetector2\dataset\backgrounds\161.png: 416x736 8 persons, 10.4ms
# image 72/195 C:\Projects\SusDetector2\dataset\backgrounds\162.png: 416x736 10 persons, 10.4ms
# image 73/195 C:\Projects\SusDetector2\dataset\backgrounds\163.png: 416x736 5 persons, 11.1ms
# image 74/195 C:\Projects\SusDetector2\dataset\backgrounds\164.png: 416x736 3 persons, 11.1ms
# image 75/195 C:\Projects\SusDetector2\dataset\backgrounds\165.png: 416x736 7 persons, 11.1ms
# image 76/195 C:\Projects\SusDetector2\dataset\backgrounds\166.png: 416x736 2 persons, 11.1ms
# image 77/195 C:\Projects\SusDetector2\dataset\backgrounds\167.png: 416x736 7 persons, 10.4ms
# image 78/195 C:\Projects\SusDetector2\dataset\backgrounds\168.png: 416x736 4 persons, 10.4ms
# image 79/195 C:\Projects\SusDetector2\dataset\backgrounds\169.png: 416x736 4 persons, 10.4ms
# image 80/195 C:\Projects\SusDetector2\dataset\backgrounds\17.png: 416x736 5 persons, 10.4ms
# image 81/195 C:\Projects\SusDetector2\dataset\backgrounds\170.png: 416x736 7 persons, 10.4ms
# image 82/195 C:\Projects\SusDetector2\dataset\backgrounds\171.png: 416x736 3 persons, 10.4ms
# image 83/195 C:\Projects\SusDetector2\dataset\backgrounds\172.png: 416x736 4 persons, 10.4ms
# image 84/195 C:\Projects\SusDetector2\dataset\backgrounds\173.png: 416x736 6 persons, 10.4ms
# image 85/195 C:\Projects\SusDetector2\dataset\backgrounds\174.png: 416x736 9 persons, 10.3ms
# image 86/195 C:\Projects\SusDetector2\dataset\backgrounds\175.png: 416x736 9 persons, 10.3ms
# image 87/195 C:\Projects\SusDetector2\dataset\backgrounds\176.png: 416x736 5 persons, 10.3ms
# image 88/195 C:\Projects\SusDetector2\dataset\backgrounds\177.png: 416x736 4 persons, 10.3ms
# image 89/195 C:\Projects\SusDetector2\dataset\backgrounds\178.png: 416x736 6 persons, 10.2ms
# image 90/195 C:\Projects\SusDetector2\dataset\backgrounds\179.png: 416x736 3 persons, 10.2ms
# image 91/195 C:\Projects\SusDetector2\dataset\backgrounds\18.png: 416x736 8 persons, 10.2ms
# image 92/195 C:\Projects\SusDetector2\dataset\backgrounds\180.png: 416x736 8 persons, 10.2ms
# image 93/195 C:\Projects\SusDetector2\dataset\backgrounds\181.png: 416x736 2 persons, 10.4ms
# image 94/195 C:\Projects\SusDetector2\dataset\backgrounds\182.png: 416x736 4 persons, 10.4ms
# image 95/195 C:\Projects\SusDetector2\dataset\backgrounds\183.png: 416x736 6 persons, 10.4ms
# image 96/195 C:\Projects\SusDetector2\dataset\backgrounds\184.png: 416x736 2 persons, 10.4ms
# image 97/195 C:\Projects\SusDetector2\dataset\backgrounds\185.png: 416x736 8 persons, 10.3ms
# image 98/195 C:\Projects\SusDetector2\dataset\backgrounds\186.png: 416x736 9 persons, 10.3ms
# image 99/195 C:\Projects\SusDetector2\dataset\backgrounds\187.png: 416x736 10 persons, 10.3ms
# image 100/195 C:\Projects\SusDetector2\dataset\backgrounds\188.png: 416x736 10 persons, 10.3ms
# image 101/195 C:\Projects\SusDetector2\dataset\backgrounds\189.png: 416x736 4 persons, 11.1ms
# image 102/195 C:\Projects\SusDetector2\dataset\backgrounds\19.png: 416x736 9 persons, 11.1ms
# image 103/195 C:\Projects\SusDetector2\dataset\backgrounds\190.png: 416x736 4 persons, 11.1ms
# image 104/195 C:\Projects\SusDetector2\dataset\backgrounds\191.png: 416x736 4 persons, 11.1ms
# image 105/195 C:\Projects\SusDetector2\dataset\backgrounds\192.png: 416x736 2 persons, 10.3ms
# image 106/195 C:\Projects\SusDetector2\dataset\backgrounds\193.png: 416x736 10 persons, 10.3ms
# image 107/195 C:\Projects\SusDetector2\dataset\backgrounds\194.png: 416x736 2 persons, 10.3ms
# image 108/195 C:\Projects\SusDetector2\dataset\backgrounds\2.png: 416x736 2 persons, 10.3ms
# image 109/195 C:\Projects\SusDetector2\dataset\backgrounds\20.png: 416x736 5 persons, 10.4ms
# image 110/195 C:\Projects\SusDetector2\dataset\backgrounds\21.png: 416x736 5 persons, 10.4ms
# image 111/195 C:\Projects\SusDetector2\dataset\backgrounds\22.png: 416x736 5 persons, 10.4ms
# image 112/195 C:\Projects\SusDetector2\dataset\backgrounds\23.png: 416x736 2 persons, 10.4ms
# image 113/195 C:\Projects\SusDetector2\dataset\backgrounds\24.png: 416x736 8 persons, 10.4ms
# image 114/195 C:\Projects\SusDetector2\dataset\backgrounds\25.png: 416x736 3 persons, 10.4ms
# image 115/195 C:\Projects\SusDetector2\dataset\backgrounds\26.png: 416x736 3 persons, 10.4ms
# image 116/195 C:\Projects\SusDetector2\dataset\backgrounds\27.png: 416x736 5 persons, 10.4ms
# image 117/195 C:\Projects\SusDetector2\dataset\backgrounds\28.png: 416x736 3 persons, 10.4ms
# image 118/195 C:\Projects\SusDetector2\dataset\backgrounds\29.png: 416x736 7 persons, 10.4ms
# image 119/195 C:\Projects\SusDetector2\dataset\backgrounds\3.png: 416x736 7 persons, 10.4ms
# image 120/195 C:\Projects\SusDetector2\dataset\backgrounds\30.png: 416x736 7 persons, 10.4ms
# image 121/195 C:\Projects\SusDetector2\dataset\backgrounds\31.png: 416x736 11 persons, 10.3ms
# image 122/195 C:\Projects\SusDetector2\dataset\backgrounds\32.png: 416x736 9 persons, 10.3ms
# image 123/195 C:\Projects\SusDetector2\dataset\backgrounds\33.png: 416x736 4 persons, 10.3ms
# image 124/195 C:\Projects\SusDetector2\dataset\backgrounds\34.png: 416x736 4 persons, 10.3ms
# image 125/195 C:\Projects\SusDetector2\dataset\backgrounds\35.png: 416x736 6 persons, 10.4ms
# image 126/195 C:\Projects\SusDetector2\dataset\backgrounds\36.png: 416x736 5 persons, 10.4ms
# image 127/195 C:\Projects\SusDetector2\dataset\backgrounds\37.png: 416x736 8 persons, 10.4ms
# image 128/195 C:\Projects\SusDetector2\dataset\backgrounds\38.png: 416x736 3 persons, 10.4ms
# image 129/195 C:\Projects\SusDetector2\dataset\backgrounds\39.png: 416x736 5 persons, 10.4ms
# image 130/195 C:\Projects\SusDetector2\dataset\backgrounds\4.png: 416x736 5 persons, 10.4ms
# image 131/195 C:\Projects\SusDetector2\dataset\backgrounds\40.png: 416x736 6 persons, 10.4ms
# image 132/195 C:\Projects\SusDetector2\dataset\backgrounds\41.png: 416x736 3 persons, 10.4ms
# image 133/195 C:\Projects\SusDetector2\dataset\backgrounds\42.png: 416x736 9 persons, 10.4ms
# image 134/195 C:\Projects\SusDetector2\dataset\backgrounds\43.png: 416x736 7 persons, 10.4ms
# image 135/195 C:\Projects\SusDetector2\dataset\backgrounds\44.png: 416x736 9 persons, 10.4ms
# image 136/195 C:\Projects\SusDetector2\dataset\backgrounds\45.png: 416x736 8 persons, 10.4ms
# image 137/195 C:\Projects\SusDetector2\dataset\backgrounds\46.png: 416x736 4 persons, 10.5ms
# image 138/195 C:\Projects\SusDetector2\dataset\backgrounds\47.png: 416x736 4 persons, 10.5ms
# image 139/195 C:\Projects\SusDetector2\dataset\backgrounds\48.png: 416x736 8 persons, 10.5ms
# image 140/195 C:\Projects\SusDetector2\dataset\backgrounds\49.png: 416x736 2 persons, 10.5ms
# image 141/195 C:\Projects\SusDetector2\dataset\backgrounds\5.png: 416x736 9 persons, 10.3ms
# image 142/195 C:\Projects\SusDetector2\dataset\backgrounds\50.png: 416x736 9 persons, 10.3ms
# image 143/195 C:\Projects\SusDetector2\dataset\backgrounds\51.png: 416x736 3 persons, 10.3ms
# image 144/195 C:\Projects\SusDetector2\dataset\backgrounds\52.png: 416x736 3 persons, 10.3ms
# image 145/195 C:\Projects\SusDetector2\dataset\backgrounds\53.png: 416x736 5 persons, 10.7ms
# image 146/195 C:\Projects\SusDetector2\dataset\backgrounds\54.png: 416x736 3 persons, 10.7ms
# image 147/195 C:\Projects\SusDetector2\dataset\backgrounds\55.png: 416x736 8 persons, 10.7ms
# image 148/195 C:\Projects\SusDetector2\dataset\backgrounds\56.png: 416x736 9 persons, 10.7ms
# image 149/195 C:\Projects\SusDetector2\dataset\backgrounds\57.png: 416x736 10 persons, 10.4ms
# image 150/195 C:\Projects\SusDetector2\dataset\backgrounds\58.png: 416x736 11 persons, 10.4ms
# image 151/195 C:\Projects\SusDetector2\dataset\backgrounds\59.png: 416x736 4 persons, 10.4ms
# image 152/195 C:\Projects\SusDetector2\dataset\backgrounds\6.png: 416x736 12 persons, 10.4ms
# image 153/195 C:\Projects\SusDetector2\dataset\backgrounds\60.png: 416x736 5 persons, 10.4ms
# image 154/195 C:\Projects\SusDetector2\dataset\backgrounds\61.png: 416x736 6 persons, 10.4ms
# image 155/195 C:\Projects\SusDetector2\dataset\backgrounds\62.png: 416x736 5 persons, 10.4ms
# image 156/195 C:\Projects\SusDetector2\dataset\backgrounds\63.png: 416x736 9 persons, 10.4ms
# image 157/195 C:\Projects\SusDetector2\dataset\backgrounds\64.png: 416x736 2 persons, 10.4ms
# image 158/195 C:\Projects\SusDetector2\dataset\backgrounds\65.png: 416x736 2 persons, 10.4ms
# image 159/195 C:\Projects\SusDetector2\dataset\backgrounds\66.png: 416x736 4 persons, 10.4ms
# image 160/195 C:\Projects\SusDetector2\dataset\backgrounds\67.png: 416x736 2 persons, 10.4ms
# image 161/195 C:\Projects\SusDetector2\dataset\backgrounds\68.png: 416x736 6 persons, 10.4ms
# image 162/195 C:\Projects\SusDetector2\dataset\backgrounds\69.png: 416x736 7 persons, 10.4ms
# image 163/195 C:\Projects\SusDetector2\dataset\backgrounds\7.png: 416x736 3 persons, 10.4ms
# image 164/195 C:\Projects\SusDetector2\dataset\backgrounds\70.png: 416x736 7 persons, 10.4ms
# image 165/195 C:\Projects\SusDetector2\dataset\backgrounds\71.png: 416x736 11 persons, 11.6ms
# image 166/195 C:\Projects\SusDetector2\dataset\backgrounds\72.png: 416x736 4 persons, 11.6ms
# image 167/195 C:\Projects\SusDetector2\dataset\backgrounds\73.png: 416x736 4 persons, 11.6ms
# image 168/195 C:\Projects\SusDetector2\dataset\backgrounds\74.png: 416x736 8 persons, 11.6ms
# image 169/195 C:\Projects\SusDetector2\dataset\backgrounds\75.png: 416x736 3 persons, 11.8ms
# image 170/195 C:\Projects\SusDetector2\dataset\backgrounds\76.png: 416x736 6 persons, 11.8ms
# image 171/195 C:\Projects\SusDetector2\dataset\backgrounds\77.png: 416x736 2 persons, 11.8ms
# image 172/195 C:\Projects\SusDetector2\dataset\backgrounds\78.png: 416x736 5 persons, 11.8ms
# image 173/195 C:\Projects\SusDetector2\dataset\backgrounds\79.png: 416x736 6 persons, 10.5ms
# image 174/195 C:\Projects\SusDetector2\dataset\backgrounds\8.png: 416x736 3 persons, 10.5ms
# image 175/195 C:\Projects\SusDetector2\dataset\backgrounds\80.png: 416x736 3 persons, 10.5ms
# image 176/195 C:\Projects\SusDetector2\dataset\backgrounds\81.png: 416x736 6 persons, 10.5ms
# image 177/195 C:\Projects\SusDetector2\dataset\backgrounds\82.png: 416x736 6 persons, 10.7ms
# image 178/195 C:\Projects\SusDetector2\dataset\backgrounds\83.png: 416x736 5 persons, 10.7ms
# image 179/195 C:\Projects\SusDetector2\dataset\backgrounds\84.png: 416x736 12 persons, 10.7ms
# image 180/195 C:\Projects\SusDetector2\dataset\backgrounds\85.png: 416x736 6 persons, 10.7ms
# image 181/195 C:\Projects\SusDetector2\dataset\backgrounds\86.png: 416x736 4 persons, 11.7ms
# image 182/195 C:\Projects\SusDetector2\dataset\backgrounds\87.png: 416x736 7 persons, 11.7ms
# image 183/195 C:\Projects\SusDetector2\dataset\backgrounds\88.png: 416x736 3 persons, 11.7ms
# image 184/195 C:\Projects\SusDetector2\dataset\backgrounds\89.png: 416x736 9 persons, 11.7ms
# image 185/195 C:\Projects\SusDetector2\dataset\backgrounds\9.png: 416x736 7 persons, 11.7ms
# image 186/195 C:\Projects\SusDetector2\dataset\backgrounds\90.png: 416x736 2 persons, 11.7ms
# image 187/195 C:\Projects\SusDetector2\dataset\backgrounds\91.png: 416x736 5 persons, 11.7ms
# image 188/195 C:\Projects\SusDetector2\dataset\backgrounds\92.png: 416x736 6 persons, 11.7ms
# image 189/195 C:\Projects\SusDetector2\dataset\backgrounds\93.png: 416x736 4 persons, 10.5ms
# image 190/195 C:\Projects\SusDetector2\dataset\backgrounds\94.png: 416x736 7 persons, 10.5ms
# image 191/195 C:\Projects\SusDetector2\dataset\backgrounds\95.png: 416x736 10 persons, 10.5ms
# image 192/195 C:\Projects\SusDetector2\dataset\backgrounds\96.png: 416x736 8 persons, 10.5ms
# image 193/195 C:\Projects\SusDetector2\dataset\backgrounds\97.png: 416x736 11 persons, 10.9ms
# image 194/195 C:\Projects\SusDetector2\dataset\backgrounds\98.png: 416x736 3 persons, 10.9ms
# image 195/195 C:\Projects\SusDetector2\dataset\backgrounds\99.png: 416x736 4 persons, 10.9ms
# Speed: 1.1ms preprocess, 10.6ms inference, 0.7ms postprocess per image at shape (4, 3, 416, 736)
# Results saved to C:\Projects\SusDetector2\dataset\people-seg
# 195 labels saved to C:\Projects\SusDetector2\dataset\people-seg\labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[ 59,  94,  82],
#          [ 57,  96,  84],
#          [ 59, 100,  87],
#          ...,
#          [ 73, 124, 107],
#          [ 75, 125, 108],
#          [ 80, 122, 109]],
#
#         [[ 58,  97,  86],
#          [ 59,  99,  88],
#          [ 62, 102,  89],
#          ...,
#          [ 66, 115,  99],
#          [ 68, 116,  96],
#          [ 74, 122, 103]],
#
#         [[ 59,  96,  84],
#          [ 63, 100,  89],
#          [ 65, 103,  91],
#          ...,
#          [ 66, 115, 100],
#          [ 66, 113,  97],
#          [ 68, 115,  98]],
#
#         ...,
#
#         [[102, 183, 174],
#          [107, 185, 175],
#          [106, 183, 172],
#          ...,
#          [ 93, 172, 159],
#          [ 96, 174, 161],
#          [ 98, 176, 163]],
#
#         [[101, 182, 172],
#          [ 96, 175, 165],
#          [102, 183, 172],
#          ...,
#          [ 94, 173, 161],
#          [ 95, 173, 160],
#          [ 94, 169, 156]],
#
#         [[109, 177, 168],
#          [ 97, 174, 164],
#          [105, 181, 170],
#          ...,
#          [ 97, 175, 164],
#          [ 94, 169, 159],
#          [105, 165, 159]]], shape=(720, 1280, 3), dtype=uint8)
#  orig_shape: (720, 1280)
#  path: 'C:\\Projects\\SusDetector2\\dataset\\backgrounds\\0.png'
#  probs: None
#  save_dir: 'C:\\Projects\\SusDetector2\\dataset\\people-seg'
#  speed: {'preprocess': 1.2443250000160333, 'inference': 12.709849999964717, 'postprocess': 0.8073500000591594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[191, 189, 169],
#          [192, 189, 169],
#          [191, 189, 169],
#          ...,
#          [249, 251, 249],
#          [251, 250, 251],
#          [247, 247, 249]],
#
#         [[189, 187, 165],
#          [191, 191, 169],
#          [187, 186, 166],
#          ...,
#          [249, 251, 249],
#          [249, 250, 247],
#          [251, 249, 249]],
#
#         [[189, 186, 165],
#          [189, 187, 167],
#          [189, 187, 167],
#          ...,
#          [249, 250, 249],
#          [250, 251, 250],
#          [250, 249, 251]],
#
#         ...,
#
#         [[202, 205, 204],
#          [203, 205, 203],
#          [202, 205, 203],
#          ...,
#          [186, 193, 193],
#          [185, 191, 193],
#          [185, 191, 195]],
#
#         [[203, 207, 207],
#          [203, 206, 205],
#          [203, 207, 205],
#          ...,
#          [187, 193, 193],
#          [185, 191, 193],
#          [185, 191, 193]],
#
#         [[205, 207, 207],
#          [205, 207, 208],
#          [207, 210, 209],
#          ...,
#          [187, 193, 194],
#          [186, 193, 194],
#          [188, 191, 193]]], shape=(720, 1280, 3), dtype=uint8)
#  orig_shape: (720, 1280)
#  path: 'C:\\Projects\\SusDetector2\\dataset\\backgrounds\\1.png'
#  probs: None
#  save_dir: 'C:\\Projects\\SusDetector2\\dataset\\people-seg'
#  speed: {'preprocess': 1.2443250000160333, 'inference': 12.709849999964717, 'postprocess': 0.8073500000591594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[178, 176, 181],
#          [180, 177, 182],
#          [181, 179, 182],
#          ...,
#          [213, 213, 209],
#          [213, 211, 209],
#          [213, 211, 209]],
#
#         [[179, 177, 181],
#          [179, 177, 181],
#          [180, 180, 182],
#          ...,
#          [213, 213, 207],
#          [213, 212, 207],
#          [215, 212, 209]],
#
#         [[179, 179, 182],
#          [179, 179, 181],
#          [179, 179, 182],
#          ...,
#          [213, 213, 208],
#          [215, 213, 209],
#          [215, 213, 209]],
#
#         ...,
#
#         [[184, 191, 193],
#          [184, 191, 191],
#          [185, 193, 193],
#          ...,
#          [155, 173, 182],
#          [153, 173, 182],
#          [154, 174, 183]],
#
#         [[183, 191, 191],
#          [185, 193, 193],
#          [184, 193, 193],
#          ...,
#          [155, 173, 183],
#          [153, 172, 182],
#          [151, 171, 181]],
#
#         [[184, 189, 191],
#          [185, 190, 193],
#          [187, 193, 195],
#          ...,
#          [155, 173, 183],
#          [153, 172, 181],
#          [156, 171, 179]]], shape=(720, 1280, 3), dtype=uint8)
#  orig_shape: (720, 1280)
#  path: 'C:\\Projects\\SusDetector2\\dataset\\backgrounds\\10.png'
#  probs: None
#  save_dir: 'C:\\Projects\\SusDetector2\\dataset\\people-seg'
#  speed: {'preprocess': 1.2443250000160333, 'inference': 12.709849999964717, 'postprocess': 0.8073500000591594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[ 67, 107, 132],
#          [ 78, 125, 167],
#          [ 57,  96, 141],
#          ...,
#          [104, 135, 177],
#          [ 99, 130, 171],
#          [ 92, 119, 157]],
#
#         [[  6,  45,  91],
#          [ 16,  62, 121],
#          [ 54,  94, 141],
#          ...,
#          [101, 134, 177],
#          [102, 132, 173],
#          [ 99, 127, 168]],
#
#         [[106, 135, 174],
#          [144, 170, 219],
#          [191, 211, 245],
#          ...,
#          [ 95, 129, 172],
#          [100, 130, 170],
#          [106, 130, 172]],
#
#         ...,
#
#         [[146, 147, 168],
#          [155, 156, 178],
#          [150, 149, 173],
#          ...,
#          [164, 169, 172],
#          [162, 169, 173],
#          [162, 167, 172]],
#
#         [[133, 137, 159],
#          [144, 143, 169],
#          [146, 145, 169],
#          ...,
#          [174, 178, 181],
#          [179, 185, 189],
#          [167, 170, 177]],
#
#         [[144, 146, 166],
#          [175, 172, 194],
#          [158, 149, 173],
#          ...,
#          [173, 176, 178],
#          [182, 185, 189],
#          [174, 173, 179]]], shape=(720, 1280, 3), dtype=uint8)
#  orig_shape: (720, 1280)
#  path: 'C:\\Projects\\SusDetector2\\dataset\\backgrounds\\100.png'
#  probs: None
#  save_dir: 'C:\\Projects\\SusDetector2\\dataset\\people-seg'
#  speed: {'preprocess': 1.2443250000160333, 'inference': 12.709849999964717, 'postprocess': 0.8073500000591594},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[ 71, 101, 127],
#          [ 64,  98, 129],
#          [ 68, 103, 134],
#          ...,
#          [ 57,  86, 114],
#          [ 73, 101, 132],
#          [ 75, 100, 130]],
#
#         [[ 71, 106, 135],
#          [ 65,  99, 130],
#          [ 67, 102, 133],
#          ...,
#          [ 80, 112, 141],
#          [ 86, 117, 149],
#          [ 80, 111, 145]],
#
#         [[ 72, 103, 131],
#          [ 67,  99, 129],
#          [ 68, 104, 135],
#          ...,
#          [ 92, 126, 157],
#          [ 86, 120, 152],
#          [ 75, 108, 142]],
#
#         ...,
#
#         [[108, 124, 140],
#          [112, 126, 141],
#          [114, 128, 143],
#          ...,
#          [198, 209, 217],
#          [198, 209, 217],
#          [197, 207, 216]],
#
#         [[102, 118, 135],
#          [109, 124, 139],
#          [112, 127, 141],
#          ...,
#          [197, 206, 215],
#          [195, 205, 214],
#          [194, 204, 213]],
#
#         [[100, 113, 128],
#          [105, 118, 134],
#          [110, 123, 139],
#          ...,
#          [193, 203, 211],
#          [192, 201, 211],
#          [194, 201, 209]]], shape=(720, 1280, 3), dtype=uint8)
#  orig_shape: (720, 1280)
#  path: 'C:\\Projects\\SusDetector2\\dataset\\backgrounds\\101.png'
#  probs: None
#  save_dir: 'C:\\Projects\\SusDetector2\\dataset\\people-seg'
#  speed: {'preprocess': 1.0996999999406398, 'inference': 10.807325000087076, 'postprocess': 0.733650000029229},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[ 44,  50,  56],
#          [ 44,  49,  55],
#          [ 45,  51,  58],
#          ...,
#          [127, 132, 140],
#          [123, 129, 139],
#          [121, 125, 137]],
#
#         [[ 45,  51,  57],
#          [ 46,  53,  58],
#          [ 46,  53,  58],
#          ...,
#          [ 83,  90,  98],
#          [ 83,  91,  99],
#          [ 80,  87,  99]],
#
#         [[ 48,  53,  58],
#          [ 48,  54,  60],
#          [ 48,  55,  60],
#          ...,
#          [ 69,  76,  87],
#          [ 69,  78,  88],
#          [ 66,  75,  87]],
#
#         ...,
#
#         [[ 57,  69,  78],
#          [ 59,  70,  79],
#          [ 61,  72,  80],
#          ...,
#          [136, 143, 155],
#          [127, 133, 146],
#          [118, 124, 137]],
#
#         [[ 60,  72,  82],
#          [ 56,  67,  77],
#          [ 59,  71,  80],
#          ...,
#          [130, 135, 147],
#          [129, 136, 148],
#          [118, 125, 137]],
#
#         [[ 61,  67,  77],
#          [ 60,  64,  73],
#          [ 58,  65,  73],
#          ...,
#          [121, 127, 138],
#          [123, 128, 140],
#          [125, 128, 139]]], shape=(720, 1280, 3), dtype=uint8)
#  orig_shape: (720, 1280)
#  path: 'C:\\Projects\\SusDetector2\\dataset\\backgrounds\\102.png'
#  probs: None
#  save_dir: 'C:\\Projects\\SusDetector2\\dataset\\people-seg'
#  speed: {'preprocess': 1.0996999999406398, 'inference': 10.807325000087076, 'postprocess': 0.733650000029229},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[ 86, 111, 144],
#          [ 75, 100, 142],
#          [ 65,  91, 133],
#          ...,
#          [152, 175, 205],
#          [154, 178, 207],
#          [146, 166, 195]],
#
#         [[ 82, 110, 147],
#          [ 72, 100, 140],
#          [ 60,  89, 130],
#          ...,
#          [158, 181, 207],
#          [165, 187, 213],
#          [158, 179, 207]],
#
#         [[ 83, 108, 142],
#          [ 72,  98, 135],
#          [ 56,  86, 125],
#          ...,
#          [163, 184, 209],
#          [169, 191, 215],
#          [157, 178, 204]],
#
#         ...,
#
#         [[110, 136, 153],
#          [126, 149, 167],
#          [137, 159, 178],
#          ...,
#          [ 92, 120, 151],
#          [ 94, 119, 150],
#          [ 93, 118, 148]],
#
#         [[100, 126, 141],
#          [116, 141, 156],
#          [130, 154, 171],
#          ...,
#          [ 89, 117, 149],
#          [ 87, 110, 144],
#          [ 89, 113, 144]],
#
#         [[ 99, 121, 133],
#          [112, 136, 151],
#          [129, 152, 168],
#          ...,
#          [ 85, 114, 147],
#          [ 80, 107, 139],
#          [ 84, 102, 130]]], shape=(720, 1280, 3), dtype=uint8)
#  orig_shape: (720, 1280)
#  path: 'C:\\Projects\\SusDetector2\\dataset\\backgrounds\\103.png'
#  probs: None
#  save_dir: 'C:\\Projects\\SusDetector2\\dataset\\people-seg'
#  speed: {'preprocess': 1.0996999999406398, 'inference': 10.807325000087076, 'postprocess': 0.733650000029229},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[ 50,  86,  77],
#          [ 47,  88,  80],
#          [ 51,  95,  86],
#          ...,
#          [ 95, 180, 184],
#          [ 92, 175, 182],
#          [101, 171, 181]],
#
#         [[ 47,  87,  79],
#          [ 47,  88,  80],
#          [ 53,  95,  86],
#          ...,
#          [ 94, 177, 182],
#          [ 98, 182, 186],
#          [102, 184, 189]],
#
#         [[ 48,  84,  74],
#          [ 51,  88,  79],
#          [ 54,  93,  84],
#          ...,
#          [ 98, 179, 185],
#          [101, 183, 187],
#          [103, 184, 189]],
#
#         ...,
#
#         [[ 56, 171, 159],
#          [ 55, 168, 155],
#          [ 58, 168, 155],
#          ...,
#          [105, 225, 223],
#          [102, 225, 226],
#          [100, 223, 223]],
#
#         [[ 75, 185, 175],
#          [ 73, 185, 174],
#          [ 64, 173, 161],
#          ...,
#          [101, 225, 222],
#          [102, 225, 225],
#          [ 91, 207, 208]],
#
#         [[110, 198, 191],
#          [110, 210, 202],
#          [100, 197, 188],
#          ...,
#          [ 95, 223, 220],
#          [103, 224, 227],
#          [113, 207, 217]]], shape=(720, 1280, 3), dtype=uint8)
#  orig_shape: (720, 1280)
#  path: 'C:\\Projects\\SusDetector2\\dataset\\backgrounds\\104.png'
#  probs: None
#  save_dir: 'C:\\Projects\\SusDetector2\\dataset\\people-seg'
#  speed: {'preprocess': 1.0996999999406398, 'inference': 10.807325000087076, 'postprocess': 0.733650000029229},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[245, 245, 241],
#          [247, 244, 241],
#          [250, 246, 243],
#          ...,
#          [206, 211, 193],
#          [205, 209, 195],
#          [205, 207, 198]],
#
#         [[245, 243, 239],
#          [247, 245, 242],
#          [247, 245, 241],
#          ...,
#          [207, 213, 197],
#          [209, 213, 199],
#          [211, 213, 203]],
#
#         [[246, 243, 240],
#          [247, 243, 241],
#          [248, 244, 242],
#          ...,
#          [209, 215, 203],
#          [211, 216, 205],
#          [211, 215, 206]],
#
#         ...,
#
#         [[231, 233, 234],
#          [234, 233, 233],
#          [236, 236, 236],
#          ...,
#          [106, 122, 128],
#          [108, 123, 130],
#          [110, 125, 132]],
#
#         [[230, 233, 235],
#          [235, 233, 237],
#          [237, 237, 237],
#          ...,
#          [107, 120, 129],
#          [105, 119, 128],
#          [108, 122, 130]],
#
#         [[237, 235, 239],
#          [237, 235, 239],
#          [239, 237, 241],
#          ...,
#          [106, 120, 129],
#          [104, 119, 127],
#          [109, 121, 126]]], shape=(720, 1280, 3), dtype=uint8)
#  orig_shape: (720, 1280)
#  path: 'C:\\Projects\\SusDetector2\\dataset\\backgrounds\\105.png'
#  probs: None
#  save_dir: 'C:\\Projects\\SusDetector2\\dataset\\people-seg'
#  speed: {'preprocess': 1.0938249999981053, 'inference': 10.653300000058152, 'postprocess': 0.7091249999575666},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[ 59,  82, 101],
#          [ 54,  78, 101],
#          [ 55,  80, 102],
#          ...,
#          [109, 173, 213],
#          [116, 175, 219],
#          [125, 174, 218]],
#
#         [[ 54,  80, 103],
#          [ 54,  80, 102],
#          [ 56,  81, 103],
#          ...,
#          [102, 167, 214],
#          [108, 168, 215],
#          [121, 177, 226]],
#
#         [[ 56,  79, 100],
#          [ 55,  80, 101],
#          [ 55,  79, 100],
#          ...,
#          [ 90, 156, 213],
#          [ 97, 159, 213],
#          [107, 166, 219]],
#
#         ...,
#
#         [[ 79, 125, 228],
#          [ 84, 128, 231],
#          [ 87, 131, 231],
#          ...,
#          [ 93, 167, 203],
#          [ 97, 169, 205],
#          [ 99, 171, 209]],
#
#         [[ 75, 124, 225],
#          [ 80, 124, 227],
#          [ 85, 128, 229],
#          ...,
#          [ 91, 167, 205],
#          [ 99, 171, 209],
#          [ 96, 167, 205]],
#
#         [[ 85, 127, 213],
#          [ 80, 123, 225],
#          [ 84, 126, 229],
#          ...,
#          [ 90, 168, 207],
#          [ 92, 168, 207],
#          [111, 170, 209]]], shape=(720, 1280, 3), dtype=uint8)
#  orig_shape: (720, 1280)
#  path: 'C:\\Projects\\SusDetector2\\dataset\\backgrounds\\106.png'
#  probs: None
#  save_dir: 'C:\\Projects\\SusDetector2\\dataset\\people-seg'
#  speed: {'preprocess': 1.0938249999981053, 'inference': 10.653300000058152, 'postprocess': 0.7091249999575666},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[ 34,  45,  53],
#          [ 34,  45,  54],
#          [ 35,  47,  56],
#          ...,
#          [251, 251, 249],
#          [251, 251, 251],
#          [251, 249, 251]],
#
#         [[ 31,  44,  54],
#          [ 35,  48,  56],
#          [ 37,  48,  56],
#          ...,
#          [250, 251, 248],
#          [249, 250, 247],
#          [252, 249, 249]],
#
#         [[ 34,  45,  54],
#          [ 35,  46,  54],
#          [ 37,  48,  55],
#          ...,
#          [250, 250, 248],
#          [250, 249, 249],
#          [250, 249, 249]],
#
#         ...,
#
#         [[101,  99, 107],
#          [ 99,  96, 105],
#          [ 99,  96, 105],
#          ...,
#          [  0,   1,   4],
#          [  0,   0,   2],
#          [  2,   1,   3]],
#
#         [[106, 104, 113],
#          [107, 105, 113],
# ...
#  obb: None
#  orig_img: array([[[ 17,  26,  25],
#          [ 14,  22,  24],
#          [ 15,  25,  25],
#          ...,
#          [219, 206, 207],
#          [205, 191, 197],
#          [182, 168, 173]],
#
#         [[ 13,  25,  25],
#          [ 15,  26,  28],
#          [ 14,  25,  26],
#          ...,
#          [190, 177, 180],
#          [151, 137, 141],
#          [112,  95, 100]],
#
#         [[ 15,  23,  25],
#          [ 14,  24,  25],
#          [ 16,  25,  26],
#          ...,
#          [ 97,  89,  89],
#          [ 64,  56,  57],
#          [ 48,  38,  37]],
#
#         ...,
#
#         [[ 51,  62,  64],
#          [ 52,  62,  63],
#          [ 51,  62,  63],
#          ...,
#          [ 68,  80, 101],
#          [ 65,  78,  99],
#          [ 66,  80, 101]],
#
#         [[ 48,  60,  62],
#          [ 49,  60,  62],
#          [ 47,  58,  60],
#          ...,
#          [ 70,  83, 102],
#          [ 66,  79, 100],
#          [ 73,  87, 106]],
#
#         [[ 50,  57,  59],
#          [ 49,  55,  59],
#          [ 48,  56,  58],
#          ...,
#          [ 68,  81,  99],
#          [ 66,  80,  97],
#          [ 71,  79,  96]]], shape=(720, 1280, 3), dtype=uint8)
#  orig_shape: (720, 1280)
#  path: 'C:\\Projects\\SusDetector2\\dataset\\backgrounds\\94.png'
#  probs: None
#  save_dir: 'C:\\Projects\\SusDetector2\\dataset\\people-seg'
#  speed: {'preprocess': 1.1088250000739208, 'inference': 10.489024999969843, 'postprocess': 0.7475249999515654},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[ 78,  77,  81],
#          [ 83,  79,  83],
#          [ 85,  82,  86],
#          ...,
#          [186, 200, 202],
#          [181, 196, 202],
#          [183, 197, 205]],
#
#         [[ 77,  76,  80],
#          [ 82,  81,  84],
#          [ 84,  82,  85],
#          ...,
#          [184, 199, 200],
#          [181, 196, 201],
#          [179, 194, 203]],
#
#         [[ 78,  76,  79],
#          [ 82,  81,  85],
#          [ 82,  80,  83],
#          ...,
#          [180, 195, 199],
#          [177, 193, 201],
#          [175, 191, 201]],
#
#         ...,
#
#         [[186, 191, 199],
#          [183, 188, 195],
#          [178, 185, 191],
#          ...,
#          [227, 225, 225],
#          [226, 226, 225],
#          [216, 215, 215]],
#
#         [[178, 185, 194],
#          [168, 173, 182],
#          [175, 181, 189],
#          ...,
#          [227, 225, 221],
#          [224, 221, 220],
#          [231, 225, 226]],
#
#         [[174, 179, 187],
#          [168, 171, 181],
#          [183, 185, 194],
#          ...,
#          [232, 227, 221],
#          [232, 228, 225],
#          [227, 218, 218]]], shape=(720, 1280, 3), dtype=uint8)
#  orig_shape: (720, 1280)
#  path: 'C:\\Projects\\SusDetector2\\dataset\\backgrounds\\95.png'
#  probs: None
#  save_dir: 'C:\\Projects\\SusDetector2\\dataset\\people-seg'
#  speed: {'preprocess': 1.1088250000739208, 'inference': 10.489024999969843, 'postprocess': 0.7475249999515654},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[ 39,  39,  39],
#          [ 34,  32,  33],
#          [ 34,  34,  34],
#          ...,
#          [191, 193, 197],
#          [191, 191, 199],
#          [191, 190, 198]],
#
#         [[ 37,  37,  37],
#          [ 35,  36,  36],
#          [ 33,  33,  33],
#          ...,
#          [187, 187, 192],
#          [189, 188, 195],
#          [190, 187, 195]],
#
#         [[ 39,  37,  37],
#          [ 36,  36,  35],
#          [ 34,  34,  33],
#          ...,
#          [180, 179, 185],
#          [182, 180, 186],
#          [184, 181, 188]],
#
#         ...,
#
#         [[171, 181, 185],
#          [170, 178, 181],
#          [171, 179, 182],
#          ...,
#          [221, 224, 222],
#          [212, 213, 217],
#          [209, 207, 211]],
#
#         [[169, 180, 184],
#          [169, 177, 181],
#          [171, 180, 183],
#          ...,
#          [211, 211, 211],
#          [210, 211, 213],
#          [215, 215, 217]],
#
#         [[166, 175, 179],
#          [170, 177, 182],
#          [173, 181, 185],
#          ...,
#          [209, 208, 208],
#          [211, 211, 211],
#          [217, 213, 213]]], shape=(720, 1280, 3), dtype=uint8)
#  orig_shape: (720, 1280)
#  path: 'C:\\Projects\\SusDetector2\\dataset\\backgrounds\\96.png'
#  probs: None
#  save_dir: 'C:\\Projects\\SusDetector2\\dataset\\people-seg'
#  speed: {'preprocess': 1.1088250000739208, 'inference': 10.489024999969843, 'postprocess': 0.7475249999515654},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[145, 181, 207],
#          [144, 181, 213],
#          [146, 183, 211],
#          ...,
#          [ 88, 151, 186],
#          [ 82, 145, 183],
#          [ 83, 137, 176]],
#
#         [[141, 183, 211],
#          [143, 183, 211],
#          [144, 183, 208],
#          ...,
#          [ 85, 148, 183],
#          [ 80, 143, 180],
#          [ 85, 146, 187]],
#
#         [[143, 183, 211],
#          [144, 184, 211],
#          [142, 181, 207],
#          ...,
#          [ 82, 144, 181],
#          [ 77, 139, 177],
#          [ 84, 146, 187]],
#
#         ...,
#
#         [[170, 213, 235],
#          [172, 213, 234],
#          [171, 211, 231],
#          ...,
#          [175, 217, 237],
#          [176, 215, 237],
#          [175, 215, 239]],
#
#         [[166, 210, 233],
#          [169, 211, 233],
#          [170, 211, 231],
#          ...,
#          [175, 215, 237],
#          [173, 211, 235],
#          [171, 210, 234]],
#
#         [[173, 211, 230],
#          [167, 207, 230],
#          [171, 211, 233],
#          ...,
#          [173, 213, 236],
#          [171, 209, 233],
#          [173, 204, 227]]], shape=(720, 1280, 3), dtype=uint8)
#  orig_shape: (720, 1280)
#  path: 'C:\\Projects\\SusDetector2\\dataset\\backgrounds\\97.png'
#  probs: None
#  save_dir: 'C:\\Projects\\SusDetector2\\dataset\\people-seg'
#  speed: {'preprocess': 1.1501666667754762, 'inference': 10.862066666959436, 'postprocess': 0.7026666668631757},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[111, 120, 129],
#          [108, 117, 128],
#          [108, 117, 128],
#          ...,
#          [124, 132, 139],
#          [123, 130, 139],
#          [125, 131, 139]],
#
#         [[109, 119, 128],
#          [109, 119, 128],
#          [108, 118, 128],
#          ...,
#          [124, 132, 138],
#          [124, 132, 138],
#          [125, 131, 139]],
#
#         [[108, 117, 127],
#          [108, 117, 128],
#          [107, 116, 127],
#          ...,
#          [124, 131, 138],
#          [124, 131, 138],
#          [125, 132, 139]],
#
#         ...,
#
#         [[104, 120, 140],
#          [104, 120, 139],
#          [104, 120, 139],
#          ...,
#          [ 84, 100, 120],
#          [ 85, 101, 126],
#          [ 91, 104, 128]],
#
#         [[105, 122, 141],
#          [107, 122, 142],
#          [105, 122, 141],
#          ...,
#          [ 17,  31,  54],
#          [ 27,  42,  68],
#          [ 53,  65,  89]],
#
#         [[111, 124, 142],
#          [108, 124, 143],
#          [108, 124, 143],
#          ...,
#          [  0,  16,  38],
#          [  2,  21,  42],
#          [ 19,  31,  48]]], shape=(720, 1280, 3), dtype=uint8)
#  orig_shape: (720, 1280)
#  path: 'C:\\Projects\\SusDetector2\\dataset\\backgrounds\\98.png'
#  probs: None
#  save_dir: 'C:\\Projects\\SusDetector2\\dataset\\people-seg'
#  speed: {'preprocess': 1.1501666667754762, 'inference': 10.862066666959436, 'postprocess': 0.7026666668631757},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[107, 127, 136],
#          [102, 123, 136],
#          [105, 125, 136],
#          ...,
#          [ 59, 149, 124],
#          [ 69, 150, 125],
#          [ 82, 141, 125]],
#
#         [[109, 130, 141],
#          [104, 125, 136],
#          [107, 128, 138],
#          ...,
#          [ 55, 139, 114],
#          [ 67, 145, 115],
#          [104, 171, 143]],
#
#         [[110, 130, 141],
#          [112, 131, 143],
#          [114, 132, 143],
#          ...,
#          [ 55, 134, 108],
#          [ 64, 139, 110],
#          [ 93, 163, 134]],
#
#         ...,
#
#         [[137, 168, 188],
#          [141, 171, 191],
#          [141, 172, 191],
#          ...,
#          [222, 234, 240],
#          [220, 233, 240],
#          [213, 225, 233]],
#
#         [[134, 165, 187],
#          [138, 168, 189],
#          [138, 171, 189],
#          ...,
#          [220, 231, 239],
#          [215, 228, 237],
#          [183, 196, 205]],
#
#         [[139, 167, 185],
#          [137, 168, 189],
#          [141, 172, 193],
#          ...,
#          [217, 229, 237],
#          [213, 227, 235],
#          [188, 197, 207]]], shape=(720, 1280, 3), dtype=uint8)
#  orig_shape: (720, 1280)
#  path: 'C:\\Projects\\SusDetector2\\dataset\\backgrounds\\99.png'
#  probs: None
#  save_dir: 'C:\\Projects\\SusDetector2\\dataset\\people-seg'
#  speed: {'preprocess': 1.1501666667754762, 'inference': 10.862066666959436, 'postprocess': 0.7026666668631757}]

# %%
boxes_xywh = [result.boxes.xywh.cpu().numpy() for result in box_results]

# %%
rows = []
for i, boxes in enumerate(boxes_xywh):
    rows.append([{'image': i, 'x': box[0], 'y': box[1], 'w': box[2], 'h': box[3]} for box in boxes])
rows
# Out:
#   Cell In[7], line 3
#     rows.append([{'image': i, 'x': box[0], 'y': box[1], 'w': box[2], 'h': box[3]} for in boxes])
#                                                                                       ^
# SyntaxError: invalid syntax

# %%
df = pd.DataFrame(rows, columns=['image','x', 'y', 'w', 'h'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\miniconda3\envs\susdetector\Lib\site-packages\pandas\core\internals\construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File ~\miniconda3\envs\susdetector\Lib\site-packages\pandas\core\internals\construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
#     987         f"{len(columns)} columns passed, passed data had "
#     988         f"{len(content)} columns"
#     989     )
#     990 if is_mi_list:
#     991     # check if nested list column, length of each sub-list should be equal
#
# AssertionError: 5 columns passed, passed data had 13 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.DataFrame(rows, columns=['image','x', 'y', 'w', 'h'])
#
# File ~\miniconda3\envs\susdetector\Lib\site-packages\pandas\core\frame.py:855, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     853     if columns is not None:
#     854         columns = ensure_index(columns)
# --> 855     arrays, columns, index = nested_data_to_arrays(
#     856         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     857         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     858         data,
#     859         columns,
#     860         index,  # type: ignore[arg-type]
#     861         dtype,
#     862     )
#     863     mgr = arrays_to_mgr(
#     864         arrays,
#     865         columns,
#    (...)    868         typ=manager,
#     869     )
#     870 else:
#
# File ~\miniconda3\envs\susdetector\Lib\site-packages\pandas\core\internals\construction.py:520, in nested_data_to_arrays(data, columns, index, dtype)
#     517 if is_named_tuple(data[0]) and columns is None:
#     518     columns = ensure_index(data[0]._fields)
# --> 520 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     521 columns = ensure_index(columns)
#     523 if index is None:
#
# File ~\miniconda3\envs\susdetector\Lib\site-packages\pandas\core\internals\construction.py:845, in to_arrays(data, columns, dtype)
#     842     data = [tuple(x) for x in data]
#     843     arr = _list_to_arrays(data)
# --> 845 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     846 return content, columns
#
# File ~\miniconda3\envs\susdetector\Lib\site-packages\pandas\core\internals\construction.py:942, in _finalize_columns_and_data(content, columns, dtype)
#     939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
# --> 942     raise ValueError(err) from err
#     944 if len(contents) and contents[0].dtype == np.object_:
#     945     contents = convert_object_array(contents, dtype=dtype)
#
# ValueError: 5 columns passed, passed data had 13 columns
